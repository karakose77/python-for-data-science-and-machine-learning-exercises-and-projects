# %% [markdown]
# # Seaborn Exercises
#
# Try to recreate the plots below. Don't worry about color schemes, just the plot itself.

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set for these exercises.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(palette="bright")
sns.set_context("notebook", font_scale=1.25)

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Exercises

# %% [markdown]
# **<p>Recreate the plot below using the titanic dataframe.</p>**
#
# <img src='mk002-seaborn_exercises/i001.png' /></a>

# %%
sns.jointplot(x="fare", y="age", data=titanic, edgecolor="w")

# %% [markdown]
# **<p>Recreate the plot below using the titanic dataframe.</p>**
#
# <img src='mk002-seaborn_exercises/i002.png' /></a>

# %%
sns.distplot(titanic["fare"], kde=False, bins=30, color="red")

# %% [markdown]
# **<p>Recreate the plot below using the titanic dataframe.</p>**
#
# <img src='mk002-seaborn_exercises/i003.png' /></a>

# %%
sns.boxplot(x="class", y="age", data=titanic, palette="rainbow")

# %% [markdown]
# **<p>Recreate the plot below using the titanic dataframe.</p>**
#
# <img src='mk002-seaborn_exercises/i004.png' /></a>

# %%
sns.swarmplot(x="class", y="age", data=titanic, palette="Set2")

# %% [markdown]
# **<p>Recreate the plot below using the titanic dataframe.</p>**
#
# <img src='mk002-seaborn_exercises/i005.png' /></a>

# %%
sns.countplot(x="sex", data=titanic)

# %% [markdown]
# **<p>Recreate the plot below using the titanic dataframe.</p>**
#
# <img src='mk002-seaborn_exercises/i006.png' /></a>

# %%
sns.heatmap(titanic.corr(), cmap="coolwarm", annot=False)

# %% [markdown]
# **<p>Recreate the plot below using the titanic dataframe.</p>**
#
# <img src='mk002-seaborn_exercises/i007.png' /></a>

# %%
fg = sns.FacetGrid(data=titanic, col="sex")
fg.map(sns.distplot, "age", kde=False, bins=10)
